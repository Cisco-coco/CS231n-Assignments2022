# %%
# This mounts your Google Drive to the Colab VM.
from google.colab import drive
drive.mount('/content/drive')

# TODO: Enter the foldername in your Drive where you have saved the unzipped
# assignment folder, e.g. 'cs231n/assignments/assignment1/'
FOLDERNAME = 'cs231n/assignments/assignment1/'
assert FOLDERNAME is not None, "[!] Enter the foldername."

# Now that we've mounted your Drive, this ensures that
# the Python interpreter of the Colab VM can load
# python files from within it.
import sys
sys.path.append('/content/drive/My Drive/{}'.format(FOLDERNAME))

# This downloads the CIFAR-10 dataset to your Drive
# if it doesn't already exist.
# %cd /content/drive/My\ Drive/$FOLDERNAME/cs231n/datasets/
# !bash get_datasets.sh
# %cd /content/drive/My\ Drive/$FOLDERNAME
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).
# /content/drive/My Drive/cs231n/assignments/assignment1/cs231n/datasets
# /content/drive/My Drive/cs231n/assignments/assignment1

# %% [markdown]
# # Image features exercise
# *Complete and hand in this completed worksheet (including its outputs and any supporting code outside of the worksheet) with your assignment submission. For more details see the [assignments page](http://vision.stanford.edu/teaching/cs231n/assignments.html) on the course website.*
#
# We have seen that we can achieve reasonable performance on an image classification task by training a linear classifier on the pixels of the input image. In this exercise we will show that we can improve our classification performance by training linear classifiers not on raw pixels but on features that are computed from the raw pixels.
#
# All of your work for this exercise will be done in this notebook.

# %%
import random
import numpy as np
from cs231n.data_utils import load_CIFAR10
import matplotlib.pyplot as plt


# %matplotlib inline
plt.rcParams['figure.figsize'] = (10.0, 8.0) # set default size of plots
plt.rcParams['image.interpolation'] = 'nearest'
plt.rcParams['image.cmap'] = 'gray'

# for auto-reloading extenrnal modules
# see http://stackoverflow.com/questions/1907993/autoreload-of-modules-in-ipython
# %load_ext autoreload
# %autoreload 2

# %% [markdown]
# ## Load data
# Similar to previous exercises, we will load CIFAR-10 data from disk.

# %%
from cs231n.features import color_histogram_hsv, hog_feature

def get_CIFAR10_data(num_training=49000, num_validation=1000, num_test=1000):
    # Load the raw CIFAR-10 data
    cifar10_dir = 'cs231n/datasets/cifar-10-batches-py'

    # Cleaning up variables to prevent loading data multiple times (which may cause memory issue)
    try:
       del X_train, y_train
       del X_test, y_test
       print('Clear previously loaded data.')
    except:
       pass

    X_train, y_train, X_test, y_test = load_CIFAR10(cifar10_dir)
    
    # Subsample the data
    mask = list(range(num_training, num_training + num_validation))
    X_val = X_train[mask]
    y_val = y_train[mask]
    mask = list(range(num_training))
    X_train = X_train[mask]
    y_train = y_train[mask]
    mask = list(range(num_test))
    X_test = X_test[mask]
    y_test = y_test[mask]
    
    return X_train, y_train, X_val, y_val, X_test, y_test

X_train, y_train, X_val, y_val, X_test, y_test = get_CIFAR10_data()

# %% [markdown]
# ## Extract Features
# For each image we will compute a Histogram of Oriented
# Gradients (HOG) as well as a color histogram using the hue channel in HSV
# color space. We form our final feature vector for each image by concatenating
# the HOG and color histogram feature vectors.
#
# Roughly speaking, HOG should capture the texture of the image while ignoring
# color information, and the color histogram represents the color of the input
# image while ignoring texture. As a result, we expect that using both together
# ought to work better than using either alone. Verifying this assumption would
# be a good thing to try for your own interest.
#
# The `hog_feature` and `color_histogram_hsv` functions both operate on a single
# image and return a feature vector for that image. The extract_features
# function takes a set of images and a list of feature functions and evaluates
# each feature function on each image, storing the results in a matrix where
# each column is the concatenation of all feature vectors for a single image.

# %%
from cs231n.features import *

num_color_bins = 10 # Number of bins in the color histogram
feature_fns = [hog_feature, lambda img: color_histogram_hsv(img, nbin=num_color_bins)]
X_train_feats = extract_features(X_train, feature_fns, verbose=True)
X_val_feats = extract_features(X_val, feature_fns)
X_test_feats = extract_features(X_test, feature_fns)

# Preprocessing: Subtract the mean feature
mean_feat = np.mean(X_train_feats, axis=0, keepdims=True)
X_train_feats -= mean_feat
X_val_feats -= mean_feat
X_test_feats -= mean_feat

# Preprocessing: Divide by standard deviation. This ensures that each feature
# has roughly the same scale.
std_feat = np.std(X_train_feats, axis=0, keepdims=True)
X_train_feats /= std_feat
X_val_feats /= std_feat
X_test_feats /= std_feat

# Preprocessing: Add a bias dimension
X_train_feats = np.hstack([X_train_feats, np.ones((X_train_feats.shape[0], 1))])
X_val_feats = np.hstack([X_val_feats, np.ones((X_val_feats.shape[0], 1))])
X_test_feats = np.hstack([X_test_feats, np.ones((X_test_feats.shape[0], 1))])
# Out:
# Done extracting features for 1000 / 49000 images
# Done extracting features for 2000 / 49000 images
# Done extracting features for 3000 / 49000 images
# Done extracting features for 4000 / 49000 images
# Done extracting features for 5000 / 49000 images
# Done extracting features for 6000 / 49000 images
# Done extracting features for 7000 / 49000 images
# Done extracting features for 8000 / 49000 images
# Done extracting features for 9000 / 49000 images
# Done extracting features for 10000 / 49000 images
# Done extracting features for 11000 / 49000 images
# Done extracting features for 12000 / 49000 images
# Done extracting features for 13000 / 49000 images
# Done extracting features for 14000 / 49000 images
# Done extracting features for 15000 / 49000 images
# Done extracting features for 16000 / 49000 images
# Done extracting features for 17000 / 49000 images
# Done extracting features for 18000 / 49000 images
# Done extracting features for 19000 / 49000 images
# Done extracting features for 20000 / 49000 images
# Done extracting features for 21000 / 49000 images
# Done extracting features for 22000 / 49000 images
# Done extracting features for 23000 / 49000 images
# Done extracting features for 24000 / 49000 images
# Done extracting features for 25000 / 49000 images
# Done extracting features for 26000 / 49000 images
# Done extracting features for 27000 / 49000 images
# Done extracting features for 28000 / 49000 images
# Done extracting features for 29000 / 49000 images
# Done extracting features for 30000 / 49000 images
# Done extracting features for 31000 / 49000 images
# Done extracting features for 32000 / 49000 images
# Done extracting features for 33000 / 49000 images
# Done extracting features for 34000 / 49000 images
# Done extracting features for 35000 / 49000 images
# Done extracting features for 36000 / 49000 images
# Done extracting features for 37000 / 49000 images
# Done extracting features for 38000 / 49000 images
# Done extracting features for 39000 / 49000 images
# Done extracting features for 40000 / 49000 images
# Done extracting features for 41000 / 49000 images
# Done extracting features for 42000 / 49000 images
# Done extracting features for 43000 / 49000 images
# Done extracting features for 44000 / 49000 images
# Done extracting features for 45000 / 49000 images
# Done extracting features for 46000 / 49000 images
# Done extracting features for 47000 / 49000 images
# Done extracting features for 48000 / 49000 images
# Done extracting features for 49000 / 49000 images

# %% [markdown]
# ## Train SVM on features
# Using the multiclass SVM code developed earlier in the assignment, train SVMs on top of the features extracted above; this should achieve better results than training SVMs directly on top of raw pixels.

# %%
# Use the validation set to tune the learning rate and regularization strength

from cs231n.classifiers.linear_classifier import LinearSVM

learning_rates = [1e-8, 2e-8, 3e-8, 5e-8, 1e-7, 3e-7]
regularization_strengths = [5e4, 8e4, 1e5, 2e5, 5e5, 1e6]

results = {}
best_val = -1
best_svm = None

################################################################################
# TODO:                                                                        #
# Use the validation set to set the learning rate and regularization strength. #
# This should be identical to the validation that you did for the SVM; save    #
# the best trained classifer in best_svm. You might also want to play          #
# with different numbers of bins in the color histogram. If you are careful    #
# you should be able to get accuracy of near 0.44 on the validation set.       #
################################################################################
# *****START OF YOUR CODE (DO NOT DELETE/MODIFY THIS LINE)*****

for lr in learning_rates:
  for reg in regularization_strengths:
    svm = LinearSVM()
    svm.train(X_train_feats, y_train, learning_rate=lr, reg=reg,
                          num_iters=1500, verbose=False)
    y_val_pred = svm.predict(X_val_feats)
    val_acc = np.mean(y_val == y_val_pred)

    y_train_pred = svm.predict(X_train_feats)
    train_acc = np.mean(y_train_pred == y_train)

    results[(lr, reg)] = (train_acc, val_acc)
    if val_acc > best_val:
      best_val = val_acc
      best_svm = svm

# *****END OF YOUR CODE (DO NOT DELETE/MODIFY THIS LINE)*****

# Print out results.
for lr, reg in sorted(results):
    train_accuracy, val_accuracy = results[(lr, reg)]
    print('lr %e reg %e train accuracy: %f val accuracy: %f' % (
                lr, reg, train_accuracy, val_accuracy))
    
print('best validation accuracy achieved: %f' % best_val)
# Out:
# lr 1.000000e-08 reg 5.000000e+04 train accuracy: 0.087653 val accuracy: 0.078000
# lr 1.000000e-08 reg 8.000000e+04 train accuracy: 0.105959 val accuracy: 0.118000
# lr 1.000000e-08 reg 1.000000e+05 train accuracy: 0.101776 val accuracy: 0.087000
# lr 1.000000e-08 reg 2.000000e+05 train accuracy: 0.204776 val accuracy: 0.213000
# lr 1.000000e-08 reg 5.000000e+05 train accuracy: 0.411878 val accuracy: 0.414000
# lr 1.000000e-08 reg 1.000000e+06 train accuracy: 0.409469 val accuracy: 0.424000
# lr 2.000000e-08 reg 5.000000e+04 train accuracy: 0.113143 val accuracy: 0.121000
# lr 2.000000e-08 reg 8.000000e+04 train accuracy: 0.198735 val accuracy: 0.197000
# lr 2.000000e-08 reg 1.000000e+05 train accuracy: 0.270531 val accuracy: 0.267000
# lr 2.000000e-08 reg 2.000000e+05 train accuracy: 0.415367 val accuracy: 0.426000
# lr 2.000000e-08 reg 5.000000e+05 train accuracy: 0.406469 val accuracy: 0.410000
# lr 2.000000e-08 reg 1.000000e+06 train accuracy: 0.410327 val accuracy: 0.387000
# lr 3.000000e-08 reg 5.000000e+04 train accuracy: 0.190592 val accuracy: 0.210000
# lr 3.000000e-08 reg 8.000000e+04 train accuracy: 0.403653 val accuracy: 0.413000
# lr 3.000000e-08 reg 1.000000e+05 train accuracy: 0.412959 val accuracy: 0.408000
# lr 3.000000e-08 reg 2.000000e+05 train accuracy: 0.413490 val accuracy: 0.422000
# lr 3.000000e-08 reg 5.000000e+05 train accuracy: 0.415061 val accuracy: 0.413000
# lr 3.000000e-08 reg 1.000000e+06 train accuracy: 0.413306 val accuracy: 0.417000
# lr 5.000000e-08 reg 5.000000e+04 train accuracy: 0.410980 val accuracy: 0.421000
# lr 5.000000e-08 reg 8.000000e+04 train accuracy: 0.414673 val accuracy: 0.416000
# lr 5.000000e-08 reg 1.000000e+05 train accuracy: 0.412694 val accuracy: 0.413000
# lr 5.000000e-08 reg 2.000000e+05 train accuracy: 0.412837 val accuracy: 0.406000
# lr 5.000000e-08 reg 5.000000e+05 train accuracy: 0.403367 val accuracy: 0.399000
# lr 5.000000e-08 reg 1.000000e+06 train accuracy: 0.391163 val accuracy: 0.387000
# lr 1.000000e-07 reg 5.000000e+04 train accuracy: 0.414571 val accuracy: 0.415000
# lr 1.000000e-07 reg 8.000000e+04 train accuracy: 0.415347 val accuracy: 0.411000
# lr 1.000000e-07 reg 1.000000e+05 train accuracy: 0.409878 val accuracy: 0.406000
# lr 1.000000e-07 reg 2.000000e+05 train accuracy: 0.411531 val accuracy: 0.412000
# lr 1.000000e-07 reg 5.000000e+05 train accuracy: 0.398469 val accuracy: 0.415000
# lr 1.000000e-07 reg 1.000000e+06 train accuracy: 0.400347 val accuracy: 0.397000
# lr 3.000000e-07 reg 5.000000e+04 train accuracy: 0.409490 val accuracy: 0.399000
# lr 3.000000e-07 reg 8.000000e+04 train accuracy: 0.407041 val accuracy: 0.401000
# lr 3.000000e-07 reg 1.000000e+05 train accuracy: 0.409816 val accuracy: 0.407000
# lr 3.000000e-07 reg 2.000000e+05 train accuracy: 0.401551 val accuracy: 0.385000
# lr 3.000000e-07 reg 5.000000e+05 train accuracy: 0.380388 val accuracy: 0.379000
# lr 3.000000e-07 reg 1.000000e+06 train accuracy: 0.370367 val accuracy: 0.350000
# best validation accuracy achieved: 0.426000

# %%
# Evaluate your trained SVM on the test set: you should be able to get at least 0.40
y_test_pred = best_svm.predict(X_test_feats)
test_accuracy = np.mean(y_test == y_test_pred)
print(test_accuracy)
# Out:
# 0.421

# %%
# An important way to gain intuition about how an algorithm works is to
# visualize the mistakes that it makes. In this visualization, we show examples
# of images that are misclassified by our current system. The first column
# shows images that our system labeled as "plane" but whose true label is
# something other than "plane".

examples_per_class = 8
classes = ['plane', 'car', 'bird', 'cat', 'deer', 'dog', 'frog', 'horse', 'ship', 'truck']
for cls, cls_name in enumerate(classes):
    idxs = np.where((y_test != cls) & (y_test_pred == cls))[0]
    idxs = np.random.choice(idxs, examples_per_class, replace=False)
    for i, idx in enumerate(idxs):
        plt.subplot(examples_per_class, len(classes), i * len(classes) + cls + 1)
        plt.imshow(X_test[idx].astype('uint8'))
        plt.axis('off')
        if i == 0:
            plt.title(cls_name)
plt.show()

# %% [markdown]
# ### Inline question 1:
# Describe the misclassification results that you see. Do they make sense?
#
#
# $\color{blue}{\textit Your Answer:}$
#
# Birds are misclassed as planes. It is  somewhat reasonable, for bird and plane share a similar shape.

# %% [markdown]
# ## Neural Network on image features
# Earlier in this assigment we saw that training a two-layer neural network on raw pixels achieved better classification performance than linear classifiers on raw pixels. In this notebook we have seen that linear classifiers on image features outperform linear classifiers on raw pixels.
#
# For completeness, we should also try training a neural network on image features. This approach should outperform all previous approaches: you should easily be able to achieve over 55% classification accuracy on the test set; our best model achieves about 60% classification accuracy.

# %%
# Preprocessing: Remove the bias dimension
# Make sure to run this cell only ONCE
print(X_train_feats.shape)
X_train_feats = X_train_feats[:, :-1]
X_val_feats = X_val_feats[:, :-1]
X_test_feats = X_test_feats[:, :-1]

print(X_train_feats.shape)
# Out:
# (49000, 155)
# (49000, 154)

# %%
from cs231n.classifiers.fc_net import TwoLayerNet
from cs231n.solver import Solver

input_dim = X_train_feats.shape[1]
hidden_dim = 500
num_classes = 10

data = {
    'X_train': X_train_feats, 
    'y_train': y_train, 
    'X_val': X_val_feats, 
    'y_val': y_val, 
    'X_test': X_test_feats, 
    'y_test': y_test, 
}

best_net = None
best_val_acc = 0

################################################################################
# TODO: Train a two-layer neural network on image features. You may want to    #
# cross-validate various parameters as in previous sections. Store your best   #
# model in the best_net variable.                                              #
################################################################################
# *****START OF YOUR CODE (DO NOT DELETE/MODIFY THIS LINE)*****

for num_epochs in [10, 15, 20]:
  for hidden_dim in [300, 500, 800, 1000]:
    print('-'*50)
    net = TwoLayerNet(input_dim, hidden_dim, num_classes)
    solver = Solver(net, data, update_rule='adam',
                    optim_config={
                          'learning_rate': 1e-4,
                          'beta1': 0.9,
                          'beta2': 0.999,
                          'epsilon': 1e-8,
                        },
                        lr_decay=0.95,
                        num_epochs=num_epochs, batch_size=256,
                        print_every=1e4)

    solver.train()
    if best_val_acc < solver.best_val_acc:
        best_val_acc = best_val_acc
        best_net   = net

# *****END OF YOUR CODE (DO NOT DELETE/MODIFY THIS LINE)*****
# Out:
# --------------------------------------------------
# (Iteration 1 / 1910) loss: 2.302594
# (Epoch 0 / 10) train acc: 0.205000; val_acc: 0.173000
# (Epoch 1 / 10) train acc: 0.353000; val_acc: 0.332000
# (Epoch 2 / 10) train acc: 0.408000; val_acc: 0.388000
# (Epoch 3 / 10) train acc: 0.462000; val_acc: 0.441000
# (Epoch 4 / 10) train acc: 0.478000; val_acc: 0.457000
# (Epoch 5 / 10) train acc: 0.480000; val_acc: 0.479000
# (Epoch 6 / 10) train acc: 0.494000; val_acc: 0.487000
# (Epoch 7 / 10) train acc: 0.500000; val_acc: 0.500000
# (Epoch 8 / 10) train acc: 0.492000; val_acc: 0.509000
# (Epoch 9 / 10) train acc: 0.528000; val_acc: 0.504000
# (Epoch 10 / 10) train acc: 0.527000; val_acc: 0.507000
# --------------------------------------------------
# (Iteration 1 / 1910) loss: 2.302574
# (Epoch 0 / 10) train acc: 0.195000; val_acc: 0.187000
# (Epoch 1 / 10) train acc: 0.375000; val_acc: 0.362000
# (Epoch 2 / 10) train acc: 0.461000; val_acc: 0.430000
# (Epoch 3 / 10) train acc: 0.495000; val_acc: 0.463000
# (Epoch 4 / 10) train acc: 0.491000; val_acc: 0.497000
# (Epoch 5 / 10) train acc: 0.520000; val_acc: 0.512000
# (Epoch 6 / 10) train acc: 0.541000; val_acc: 0.509000
# (Epoch 7 / 10) train acc: 0.516000; val_acc: 0.517000
# (Epoch 8 / 10) train acc: 0.555000; val_acc: 0.517000
# (Epoch 9 / 10) train acc: 0.516000; val_acc: 0.519000
# (Epoch 10 / 10) train acc: 0.545000; val_acc: 0.521000
# --------------------------------------------------
# (Iteration 1 / 1910) loss: 2.302566
# (Epoch 0 / 10) train acc: 0.209000; val_acc: 0.199000
# (Epoch 1 / 10) train acc: 0.405000; val_acc: 0.381000
# (Epoch 2 / 10) train acc: 0.442000; val_acc: 0.470000
# (Epoch 3 / 10) train acc: 0.519000; val_acc: 0.502000
# (Epoch 4 / 10) train acc: 0.486000; val_acc: 0.504000
# (Epoch 5 / 10) train acc: 0.525000; val_acc: 0.509000
# (Epoch 6 / 10) train acc: 0.551000; val_acc: 0.520000
# (Epoch 7 / 10) train acc: 0.526000; val_acc: 0.519000
# (Epoch 8 / 10) train acc: 0.555000; val_acc: 0.513000
# (Epoch 9 / 10) train acc: 0.546000; val_acc: 0.521000
# (Epoch 10 / 10) train acc: 0.558000; val_acc: 0.523000
# --------------------------------------------------
# (Iteration 1 / 1910) loss: 2.302555
# (Epoch 0 / 10) train acc: 0.222000; val_acc: 0.240000
# (Epoch 1 / 10) train acc: 0.403000; val_acc: 0.401000
# (Epoch 2 / 10) train acc: 0.467000; val_acc: 0.482000
# (Epoch 3 / 10) train acc: 0.520000; val_acc: 0.510000
# (Epoch 4 / 10) train acc: 0.500000; val_acc: 0.510000
# (Epoch 5 / 10) train acc: 0.531000; val_acc: 0.513000
# (Epoch 6 / 10) train acc: 0.542000; val_acc: 0.511000
# (Epoch 7 / 10) train acc: 0.520000; val_acc: 0.513000
# (Epoch 8 / 10) train acc: 0.558000; val_acc: 0.519000
# (Epoch 9 / 10) train acc: 0.551000; val_acc: 0.525000
# (Epoch 10 / 10) train acc: 0.560000; val_acc: 0.529000
# --------------------------------------------------
# (Iteration 1 / 2865) loss: 2.302592
# (Epoch 0 / 15) train acc: 0.190000; val_acc: 0.185000
# (Epoch 1 / 15) train acc: 0.332000; val_acc: 0.326000
# (Epoch 2 / 15) train acc: 0.406000; val_acc: 0.411000
# (Epoch 3 / 15) train acc: 0.468000; val_acc: 0.435000
# (Epoch 4 / 15) train acc: 0.488000; val_acc: 0.469000
# (Epoch 5 / 15) train acc: 0.465000; val_acc: 0.487000
# (Epoch 6 / 15) train acc: 0.499000; val_acc: 0.503000
# (Epoch 7 / 15) train acc: 0.528000; val_acc: 0.511000
# (Epoch 8 / 15) train acc: 0.531000; val_acc: 0.516000
# (Epoch 9 / 15) train acc: 0.529000; val_acc: 0.524000
# (Epoch 10 / 15) train acc: 0.558000; val_acc: 0.514000
# (Epoch 11 / 15) train acc: 0.512000; val_acc: 0.515000
# (Epoch 12 / 15) train acc: 0.509000; val_acc: 0.515000
# (Epoch 13 / 15) train acc: 0.522000; val_acc: 0.514000
# (Epoch 14 / 15) train acc: 0.530000; val_acc: 0.516000
# (Epoch 15 / 15) train acc: 0.537000; val_acc: 0.518000
# --------------------------------------------------
# (Iteration 1 / 2865) loss: 2.302588
# (Epoch 0 / 15) train acc: 0.183000; val_acc: 0.186000
# (Epoch 1 / 15) train acc: 0.357000; val_acc: 0.354000
# (Epoch 2 / 15) train acc: 0.454000; val_acc: 0.431000
# (Epoch 3 / 15) train acc: 0.480000; val_acc: 0.467000
# (Epoch 4 / 15) train acc: 0.505000; val_acc: 0.505000
# (Epoch 5 / 15) train acc: 0.521000; val_acc: 0.506000
# (Epoch 6 / 15) train acc: 0.486000; val_acc: 0.511000
# (Epoch 7 / 15) train acc: 0.498000; val_acc: 0.518000
# (Epoch 8 / 15) train acc: 0.548000; val_acc: 0.523000
# (Epoch 9 / 15) train acc: 0.527000; val_acc: 0.519000
# (Epoch 10 / 15) train acc: 0.556000; val_acc: 0.515000
# (Epoch 11 / 15) train acc: 0.532000; val_acc: 0.524000
# (Epoch 12 / 15) train acc: 0.542000; val_acc: 0.520000
# (Epoch 13 / 15) train acc: 0.559000; val_acc: 0.524000
# (Epoch 14 / 15) train acc: 0.546000; val_acc: 0.523000
# (Epoch 15 / 15) train acc: 0.546000; val_acc: 0.520000
# --------------------------------------------------
# (Iteration 1 / 2865) loss: 2.302593
# (Epoch 0 / 15) train acc: 0.234000; val_acc: 0.250000
# (Epoch 1 / 15) train acc: 0.372000; val_acc: 0.383000
# (Epoch 2 / 15) train acc: 0.468000; val_acc: 0.470000
# (Epoch 3 / 15) train acc: 0.508000; val_acc: 0.500000
# (Epoch 4 / 15) train acc: 0.476000; val_acc: 0.515000
# (Epoch 5 / 15) train acc: 0.541000; val_acc: 0.527000
# (Epoch 6 / 15) train acc: 0.545000; val_acc: 0.521000
# (Epoch 7 / 15) train acc: 0.530000; val_acc: 0.518000
# (Epoch 8 / 15) train acc: 0.540000; val_acc: 0.517000
# (Epoch 9 / 15) train acc: 0.532000; val_acc: 0.528000
# (Epoch 10 / 15) train acc: 0.538000; val_acc: 0.526000
# (Epoch 11 / 15) train acc: 0.575000; val_acc: 0.525000
# (Epoch 12 / 15) train acc: 0.536000; val_acc: 0.531000
# (Epoch 13 / 15) train acc: 0.546000; val_acc: 0.534000
# (Epoch 14 / 15) train acc: 0.553000; val_acc: 0.543000
# (Epoch 15 / 15) train acc: 0.574000; val_acc: 0.546000
# --------------------------------------------------
# (Iteration 1 / 2865) loss: 2.302582
# (Epoch 0 / 15) train acc: 0.244000; val_acc: 0.200000
# (Epoch 1 / 15) train acc: 0.389000; val_acc: 0.397000
# (Epoch 2 / 15) train acc: 0.488000; val_acc: 0.469000
# (Epoch 3 / 15) train acc: 0.515000; val_acc: 0.505000
# (Epoch 4 / 15) train acc: 0.496000; val_acc: 0.513000
# (Epoch 5 / 15) train acc: 0.523000; val_acc: 0.517000
# (Epoch 6 / 15) train acc: 0.538000; val_acc: 0.517000
# (Epoch 7 / 15) train acc: 0.542000; val_acc: 0.526000
# (Epoch 8 / 15) train acc: 0.532000; val_acc: 0.524000
# (Epoch 9 / 15) train acc: 0.554000; val_acc: 0.540000
# (Epoch 10 / 15) train acc: 0.580000; val_acc: 0.536000
# (Epoch 11 / 15) train acc: 0.554000; val_acc: 0.546000
# (Epoch 12 / 15) train acc: 0.536000; val_acc: 0.547000
# (Epoch 13 / 15) train acc: 0.575000; val_acc: 0.547000
# (Epoch 14 / 15) train acc: 0.585000; val_acc: 0.548000
# (Epoch 15 / 15) train acc: 0.611000; val_acc: 0.544000
# --------------------------------------------------
# (Iteration 1 / 3820) loss: 2.302577
# (Epoch 0 / 20) train acc: 0.268000; val_acc: 0.227000
# (Epoch 1 / 20) train acc: 0.348000; val_acc: 0.338000
# (Epoch 2 / 20) train acc: 0.441000; val_acc: 0.391000
# (Epoch 3 / 20) train acc: 0.445000; val_acc: 0.453000
# (Epoch 4 / 20) train acc: 0.480000; val_acc: 0.468000
# (Epoch 5 / 20) train acc: 0.504000; val_acc: 0.490000
# (Epoch 6 / 20) train acc: 0.507000; val_acc: 0.498000
# (Epoch 7 / 20) train acc: 0.516000; val_acc: 0.498000
# (Epoch 8 / 20) train acc: 0.504000; val_acc: 0.516000
# (Epoch 9 / 20) train acc: 0.531000; val_acc: 0.517000
# (Epoch 10 / 20) train acc: 0.531000; val_acc: 0.519000
# (Epoch 11 / 20) train acc: 0.517000; val_acc: 0.515000
# (Epoch 12 / 20) train acc: 0.524000; val_acc: 0.517000
# (Epoch 13 / 20) train acc: 0.523000; val_acc: 0.513000
# (Epoch 14 / 20) train acc: 0.546000; val_acc: 0.520000
# (Epoch 15 / 20) train acc: 0.540000; val_acc: 0.520000
# (Epoch 16 / 20) train acc: 0.532000; val_acc: 0.521000
# (Epoch 17 / 20) train acc: 0.533000; val_acc: 0.524000
# (Epoch 18 / 20) train acc: 0.539000; val_acc: 0.522000
# (Epoch 19 / 20) train acc: 0.550000; val_acc: 0.523000
# (Epoch 20 / 20) train acc: 0.540000; val_acc: 0.520000
# --------------------------------------------------
# (Iteration 1 / 3820) loss: 2.302585
# (Epoch 0 / 20) train acc: 0.214000; val_acc: 0.208000
# (Epoch 1 / 20) train acc: 0.352000; val_acc: 0.353000
# (Epoch 2 / 20) train acc: 0.458000; val_acc: 0.423000
# (Epoch 3 / 20) train acc: 0.461000; val_acc: 0.474000
# (Epoch 4 / 20) train acc: 0.460000; val_acc: 0.498000
# (Epoch 5 / 20) train acc: 0.498000; val_acc: 0.507000
# (Epoch 6 / 20) train acc: 0.523000; val_acc: 0.512000
# (Epoch 7 / 20) train acc: 0.514000; val_acc: 0.514000
# (Epoch 8 / 20) train acc: 0.539000; val_acc: 0.517000
# (Epoch 9 / 20) train acc: 0.537000; val_acc: 0.515000
# (Epoch 10 / 20) train acc: 0.560000; val_acc: 0.520000
# (Epoch 11 / 20) train acc: 0.542000; val_acc: 0.526000
# (Epoch 12 / 20) train acc: 0.512000; val_acc: 0.528000
# (Epoch 13 / 20) train acc: 0.527000; val_acc: 0.528000
# (Epoch 14 / 20) train acc: 0.552000; val_acc: 0.527000
# (Epoch 15 / 20) train acc: 0.544000; val_acc: 0.530000
# (Epoch 16 / 20) train acc: 0.535000; val_acc: 0.534000
# (Epoch 17 / 20) train acc: 0.543000; val_acc: 0.537000
# (Epoch 18 / 20) train acc: 0.542000; val_acc: 0.540000
# (Epoch 19 / 20) train acc: 0.576000; val_acc: 0.535000
# (Epoch 20 / 20) train acc: 0.560000; val_acc: 0.536000
# --------------------------------------------------
# (Iteration 1 / 3820) loss: 2.302604
# (Epoch 0 / 20) train acc: 0.242000; val_acc: 0.282000
# (Epoch 1 / 20) train acc: 0.391000; val_acc: 0.394000
# (Epoch 2 / 20) train acc: 0.481000; val_acc: 0.456000
# (Epoch 3 / 20) train acc: 0.500000; val_acc: 0.495000
# (Epoch 4 / 20) train acc: 0.499000; val_acc: 0.513000
# (Epoch 5 / 20) train acc: 0.530000; val_acc: 0.523000
# (Epoch 6 / 20) train acc: 0.540000; val_acc: 0.515000
# (Epoch 7 / 20) train acc: 0.521000; val_acc: 0.514000
# (Epoch 8 / 20) train acc: 0.522000; val_acc: 0.525000
# (Epoch 9 / 20) train acc: 0.543000; val_acc: 0.525000
# (Epoch 10 / 20) train acc: 0.571000; val_acc: 0.531000
# (Epoch 11 / 20) train acc: 0.549000; val_acc: 0.528000
# (Epoch 12 / 20) train acc: 0.550000; val_acc: 0.527000
# (Epoch 13 / 20) train acc: 0.567000; val_acc: 0.537000
# (Epoch 14 / 20) train acc: 0.563000; val_acc: 0.539000
# (Epoch 15 / 20) train acc: 0.535000; val_acc: 0.539000
# (Epoch 16 / 20) train acc: 0.562000; val_acc: 0.541000
# (Epoch 17 / 20) train acc: 0.592000; val_acc: 0.540000
# (Epoch 18 / 20) train acc: 0.578000; val_acc: 0.546000
# (Epoch 19 / 20) train acc: 0.605000; val_acc: 0.553000
# (Epoch 20 / 20) train acc: 0.558000; val_acc: 0.548000
# --------------------------------------------------
# (Iteration 1 / 3820) loss: 2.302580
# (Epoch 0 / 20) train acc: 0.235000; val_acc: 0.257000
# (Epoch 1 / 20) train acc: 0.410000; val_acc: 0.395000
# (Epoch 2 / 20) train acc: 0.474000; val_acc: 0.477000
# (Epoch 3 / 20) train acc: 0.521000; val_acc: 0.511000
# (Epoch 4 / 20) train acc: 0.507000; val_acc: 0.518000
# (Epoch 5 / 20) train acc: 0.530000; val_acc: 0.520000
# (Epoch 6 / 20) train acc: 0.530000; val_acc: 0.528000
# (Epoch 7 / 20) train acc: 0.524000; val_acc: 0.525000
# (Epoch 8 / 20) train acc: 0.544000; val_acc: 0.531000
# (Epoch 9 / 20) train acc: 0.541000; val_acc: 0.525000
# (Epoch 10 / 20) train acc: 0.550000; val_acc: 0.526000
# (Epoch 11 / 20) train acc: 0.541000; val_acc: 0.540000
# (Epoch 12 / 20) train acc: 0.584000; val_acc: 0.539000
# (Epoch 13 / 20) train acc: 0.556000; val_acc: 0.539000
# (Epoch 14 / 20) train acc: 0.556000; val_acc: 0.537000
# (Epoch 15 / 20) train acc: 0.586000; val_acc: 0.544000
# (Epoch 16 / 20) train acc: 0.573000; val_acc: 0.554000
# (Epoch 17 / 20) train acc: 0.589000; val_acc: 0.550000
# (Epoch 18 / 20) train acc: 0.569000; val_acc: 0.557000
# (Epoch 19 / 20) train acc: 0.584000; val_acc: 0.551000
# (Epoch 20 / 20) train acc: 0.592000; val_acc: 0.555000

# %%
# Run your best neural net classifier on the test set. You should be able
# to get more than 55% accuracy.

y_test_pred = np.argmax(best_net.loss(data['X_test']), axis=1)
test_acc = (y_test_pred == data['y_test']).mean()
print(test_acc)
# Out:
# 0.545
